# %%
#-----------------------------------
# Version: 1.0.0
# date(m/d/a):12/22/2023
# project: analyzing bad bunny musical data
#------------------------------------

# Goal:
# analyzing bad bunny songs
# identifying top songs in chile
# using the
# table exploration:
# rows: 173
# fields 14
# fields contained are:
# name, popularity, album, release, danceability, energy, key, loudness, speechiness , acousticness .
# tempo, intrumentalness, valence and duration

import pandas as pd
import plotly.express as px

df_bad_bunny = pd.read_csv("bad_bunny.csv")
df_bad_bunny
# Out:
#                      Name  Popularity                                Album  \
# 0                 200 Mph          74                             X 100PRE
# 1                    25/8          79                             YHLQMDLG
# 2                      <3          77                             YHLQMDLG
# 3          Ahora Me Llama          63                       Ahora Me Llama
# 4    Amantes de una Noche          71                 Amantes de una Noche
# ..                    ...         ...                                  ...
# 168           PERRO NEGRO          96  nadie sabe lo que va a pasar mañana
# 169                EUROPA          27  nadie sabe lo que va a pasar mañana
# 170               ACHO PR          76  nadie sabe lo que va a pasar mañana
# 171            UN PREVIEW          81  nadie sabe lo que va a pasar mañana
# 172          MOJABI GHOST          84                                 DATA
#
#         Release  Danceability  Energy   Key  Loudness  Speechiness  \
# 0    2018-12-23         0.850   0.500   8.0    -6.708       0.0665
# 1    2020-02-29         0.761   0.732   4.0    -5.469       0.0549
# 2    2020-02-29         0.631   0.665  10.0    -7.589       0.2290
# 3    2017-05-26         0.652   0.577   7.0    -5.273       0.0373
# 4    2018-01-12         0.567   0.730   9.0    -6.748       0.2130
# ..          ...           ...     ...   ...       ...          ...
# 168  2023-10-13         0.911   0.778   5.0    -2.248       0.2620
# 169  2023-10-13           NaN     NaN   NaN       NaN          NaN
# 170  2023-10-13         0.541   0.796   7.0    -5.177       0.3470
# 171  2023-10-13         0.795   0.815   1.0    -3.322       0.0821
# 172  2023-06-29         0.782   0.787   9.0    -2.533       0.0334
#
#      Acousticness    Tempo  Instrumentalness  Valence  Duration
# 0         0.01390  160.020          0.000384    0.816   170.509
# 1         0.09200  151.982          0.000000    0.542   243.276
# 2         0.60200   80.353          0.000002    0.634   157.967
# 3         0.00947  134.987          0.000040    0.123   233.293
# 4         0.35300   87.237          0.000002    0.525   225.520
# ..            ...      ...               ...      ...       ...
# 168       0.08870   96.057          0.000022    0.345   162.768
# 169           NaN      NaN               NaN      NaN       NaN
# 170       0.31700   85.205          0.000000    0.469   359.648
# 171       0.03680   94.991          0.000038    0.334   165.582
# 172       0.01250  122.021          0.000060    0.533   232.131
#
# [173 rows x 14 columns]

# %%
# converting field "release" to date format type
# once the data type is converted it is updated in the field Release to ensure the type is updated

df_bad_bunny["Release"] = pd.to_datetime(df_bad_bunny["Release"])

# %%
# creating custom function get era(date):
# argument is date field to clasify based on the release
# clasifying songs that are from a speficic album era or colaboration era of the songs bad bunny has taken out

def get_era(date):
  if date == pd.to_datetime("2019-06-28"):
    return("Oasis")
  if date == pd.to_datetime("2020-05-10"):
    return("Las Que No Iban A Salir")
  if date < pd.to_datetime("2018-12-23"):
    return(" Dj Luian-bad bunny")
  elif date < pd.to_datetime("2020-02-29"):
    return("X 100PRE")
  elif date < pd.to_datetime("2020-11-27"):
    return("YHLQMDLG")
  elif date < pd.to_datetime("2022-05-06"):
    return("El Ultimo Tour del Mundo")
  elif date < pd.to_datetime("2023-10-13"):
    return("Un Verano Sin Ti")
  else:
    return "nadie sabe lo que va a pasar mañana"
# creating custum function is_lb(album):
# takes as argument the field album and outputs classification based on the contained album name
# based on the information it classifies in album or single
def is_lp(album):
  if album in [
      "X 100PRE","OASIS","YHLQMDLG",
      "LAS QUE NO IBAN A SALIR", "El ÚLTIMO TOUR DEL MUNDO",
      "Un Verano Sin Ti", "nadie sabe lo que va a pasar mañana"
  ]:
    return "Album"
  else:
    return "Single"

# %%
# Creating calculated field Era:
# running the get_ era function while running all values from the dataframe Release field

df_bad_bunny["Era"] = df_bad_bunny["Release"].map(get_era)

# %%
# creating calculated field LP:
# running the is_lp function using Album dataframe values as the argument
df_bad_bunny["LP"] = df_bad_bunny["Album"].map(is_lp)

# %%
df_bad_bunny
# Out:
#                      Name  Popularity                                Album  \
# 0                 200 Mph          74                             X 100PRE
# 1                    25/8          79                             YHLQMDLG
# 2                      <3          77                             YHLQMDLG
# 3          Ahora Me Llama          63                       Ahora Me Llama
# 4    Amantes de una Noche          71                 Amantes de una Noche
# ..                    ...         ...                                  ...
# 168           PERRO NEGRO          96  nadie sabe lo que va a pasar mañana
# 169                EUROPA          27  nadie sabe lo que va a pasar mañana
# 170               ACHO PR          76  nadie sabe lo que va a pasar mañana
# 171            UN PREVIEW          81  nadie sabe lo que va a pasar mañana
# 172          MOJABI GHOST          84                                 DATA
#
#        Release  Danceability  Energy   Key  Loudness  Speechiness  \
# 0   2018-12-23         0.850   0.500   8.0    -6.708       0.0665
# 1   2020-02-29         0.761   0.732   4.0    -5.469       0.0549
# 2   2020-02-29         0.631   0.665  10.0    -7.589       0.2290
# 3   2017-05-26         0.652   0.577   7.0    -5.273       0.0373
# 4   2018-01-12         0.567   0.730   9.0    -6.748       0.2130
# ..         ...           ...     ...   ...       ...          ...
# 168 2023-10-13         0.911   0.778   5.0    -2.248       0.2620
# 169 2023-10-13           NaN     NaN   NaN       NaN          NaN
# 170 2023-10-13         0.541   0.796   7.0    -5.177       0.3470
# 171 2023-10-13         0.795   0.815   1.0    -3.322       0.0821
# 172 2023-06-29         0.782   0.787   9.0    -2.533       0.0334
#
#      Acousticness    Tempo  Instrumentalness  Valence  Duration  \
# 0         0.01390  160.020          0.000384    0.816   170.509
# 1         0.09200  151.982          0.000000    0.542   243.276
# 2         0.60200   80.353          0.000002    0.634   157.967
# 3         0.00947  134.987          0.000040    0.123   233.293
# 4         0.35300   87.237          0.000002    0.525   225.520
# ..            ...      ...               ...      ...       ...
# 168       0.08870   96.057          0.000022    0.345   162.768
# 169           NaN      NaN               NaN      NaN       NaN
# 170       0.31700   85.205          0.000000    0.469   359.648
# 171       0.03680   94.991          0.000038    0.334   165.582
# 172       0.01250  122.021          0.000060    0.533   232.131
#
#                                      Era      LP
# 0                               X 100PRE   Album
# 1                               YHLQMDLG   Album
# 2                               YHLQMDLG   Album
# 3                     Dj Luian-bad bunny  Single
# 4                     Dj Luian-bad bunny  Single
# ..                                   ...     ...
# 168  nadie sabe lo que va a pasar mañana   Album
# 169  nadie sabe lo que va a pasar mañana   Album
# 170  nadie sabe lo que va a pasar mañana   Album
# 171  nadie sabe lo que va a pasar mañana   Album
# 172                     Un Verano Sin Ti  Single
#
# [173 rows x 16 columns]

# %%
# creating table df_bad_bunny_album:
# removing null values using .dropna()
# filering values using .query for LP == Album
df_bad_bunny_album = df_bad_bunny.query("LP == 'Album'").dropna()

# %%
# displaying df_bad_bunny_album data
df_bad_bunny_album
# Out:
#                     Name  Popularity                                Album  \
# 0                200 Mph          74                             X 100PRE
# 1                   25/8          79                             YHLQMDLG
# 2                     <3          77                             YHLQMDLG
# 9          BAD CON NICKY          75              LAS QUE NO IBAN A SALIR
# 12           BENDICIONES          73              LAS QUE NO IBAN A SALIR
# ..                   ...         ...                                  ...
# 166       WHERE SHE GOES          81  nadie sabe lo que va a pasar mañana
# 167  THUNDER Y LIGHTNING          81  nadie sabe lo que va a pasar mañana
# 168          PERRO NEGRO          96  nadie sabe lo que va a pasar mañana
# 170              ACHO PR          76  nadie sabe lo que va a pasar mañana
# 171           UN PREVIEW          81  nadie sabe lo que va a pasar mañana
#
#        Release  Danceability  Energy   Key  Loudness  Speechiness  \
# 0   2018-12-23         0.850   0.500   8.0    -6.708       0.0665
# 1   2020-02-29         0.761   0.732   4.0    -5.469       0.0549
# 2   2020-02-29         0.631   0.665  10.0    -7.589       0.2290
# 9   2020-05-10         0.590   0.729   7.0    -4.950       0.0893
# 12  2020-05-10         0.828   0.581  11.0    -9.909       0.0725
# ..         ...           ...     ...   ...       ...          ...
# 166 2023-10-13         0.651   0.799   9.0    -4.020       0.0611
# 167 2023-10-13         0.552   0.744   4.0    -2.656       0.1240
# 168 2023-10-13         0.911   0.778   5.0    -2.248       0.2620
# 170 2023-10-13         0.541   0.796   7.0    -5.177       0.3470
# 171 2023-10-13         0.795   0.815   1.0    -3.322       0.0821
#
#      Acousticness    Tempo  Instrumentalness  Valence  Duration  \
# 0          0.0139  160.020          0.000384    0.816   170.509
# 1          0.0920  151.982          0.000000    0.542   243.276
# 2          0.6020   80.353          0.000002    0.634   157.967
# 9          0.3210   93.094          0.000000    0.712   202.240
# 12         0.0378  143.995          0.000000    0.843   155.060
# ..            ...      ...               ...      ...       ...
# 166        0.1430  143.992          0.634000    0.223   231.704
# 167        0.4960  156.027          0.000000    0.627   217.133
# 168        0.0887   96.057          0.000022    0.345   162.768
# 170        0.3170   85.205          0.000000    0.469   359.648
# 171        0.0368   94.991          0.000038    0.334   165.582
#
#                                      Era     LP
# 0                               X 100PRE  Album
# 1                               YHLQMDLG  Album
# 2                               YHLQMDLG  Album
# 9                Las Que No Iban A Salir  Album
# 12               Las Que No Iban A Salir  Album
# ..                                   ...    ...
# 166  nadie sabe lo que va a pasar mañana  Album
# 167  nadie sabe lo que va a pasar mañana  Album
# 168  nadie sabe lo que va a pasar mañana  Album
# 170  nadie sabe lo que va a pasar mañana  Album
# 171  nadie sabe lo que va a pasar mañana  Album
#
# [97 rows x 16 columns]

# %%
# scatter plot analysis : Exploring the Connection Between Valence and Tempo in Bad Bunny Music
# Comparing the Valance and tempo in the bad bunny music to demostrate and
# to ilustrate the relationship between emotional positivity(Valence) of a song and it's tempo

px.scatter(
    df_bad_bunny_album,
    x = "Tempo", y = "Valence",
    color = "Album",
    hover_data= "Name",
    title= "Exploring the Connection Between Valence and Tempo in Bad Bunny Music"
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4331eb11-d354-437c-ad71-7953e614793d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4331eb11-d354-437c-ad71-7953e614793d")) {                    Plotly.newPlot(                        "4331eb11-d354-437c-ad71-7953e614793d",                        [{"customdata":[["200 Mph"],["Caro"],["Como Antes"],["Cuando Perriabas"],["Estamos Bien"],["NI BIEN NI MAL"],["\u00bfQuien Tu Eres?"],["Tenemos Que Hablar"],["Otra Noche en Miami"],["Ser Bichote"],["Si Estuvi\u00e9semos Juntos"],["Solo de Mi"],["La Romana"],["RLNDT"],["MIA"]],"hovertemplate":"Album=X 100PRE\u003cbr\u003eTempo=%{x}\u003cbr\u003eValence=%{y}\u003cbr\u003eName=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"X 100PRE","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X 100PRE","orientation":"v","showlegend":true,"x":[160.02,160.007,103.956,81.998,119.883,128.028,137.048,146.075,88.661,154.946,171.854,179.972,125.8,108.025,97.054],"xaxis":"x","y":[0.816,0.248,0.252,0.499,0.439,0.337,0.325,0.144,0.297,0.183,0.158,0.15,0.326,0.142,0.156],"yaxis":"y","type":"scatter"},{"customdata":[["25\u002f8"],["\u003c3"],["Bichiyal"],["Est\u00e1 Cabr\u00f3n Ser Yo"],["Hablamos Ma\u00f1ana"],["Ignorantes"],["Si Veo a Tu Mam\u00e1"],["La Dif\u00edcil"],["Pero Ya No"],["La Santa"],["Yo Perreo Sola"],["Soli\u00e1"],["La Zona"],["Que Malo"],["Vete"],["A Tu Merced"],["Una Vez"],["Safaera"],["Puesto Pa' Guerrial"],["P FKN R"]],"hovertemplate":"Album=YHLQMDLG\u003cbr\u003eTempo=%{x}\u003cbr\u003eValence=%{y}\u003cbr\u003eName=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YHLQMDLG","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"YHLQMDLG","orientation":"v","showlegend":true,"x":[151.982,80.353,93.956,154.083,156.019,96.029,129.928,179.87,147.982,93.037,97.014,92.041,93.992,94.026,91.976,92.023,83.836,96.172,139.968,101.024],"xaxis":"x","y":[0.542,0.634,0.662,0.879,0.514,0.505,0.824,0.761,0.742,0.586,0.453,0.184,0.81,0.446,0.526,0.887,0.543,0.685,0.658,0.528],"yaxis":"y","type":"scatter"},{"customdata":[["BAD CON NICKY"],["BENDICIONES"],["BYE ME FUI"],["CANCI\u00d3N CON YANDEL"],["C\u00d3MO SE SIENTE - Remix"],["EN CASITA"],["SI ELLA SALE"],["M\u00c1S DE UNA CITA"],["PA' ROMPERLA"],["RONCA FREESTYLE"]],"hovertemplate":"Album=LAS QUE NO IBAN A SALIR\u003cbr\u003eTempo=%{x}\u003cbr\u003eValence=%{y}\u003cbr\u003eName=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAS QUE NO IBAN A SALIR","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"LAS QUE NO IBAN A SALIR","orientation":"v","showlegend":true,"x":[93.094,143.995,179.788,79.968,93.0,158.093,147.967,92.976,94.011,90.041],"xaxis":"x","y":[0.712,0.843,0.588,0.495,0.347,0.675,0.92,0.317,0.697,0.586],"yaxis":"y","type":"scatter"},{"customdata":[["COMO UN BEB\u00c9"],["CUIDAO POR AH\u00cd"],["MOJAITA"],["YO LE LLEGO"],["QUE PRETENDES"],["LA CANCI\u00d3N"],["UN PESO"],["ODIO"]],"hovertemplate":"Album=OASIS\u003cbr\u003eTempo=%{x}\u003cbr\u003eValence=%{y}\u003cbr\u003eName=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OASIS","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"OASIS","orientation":"v","showlegend":true,"x":[103.053,90.98,172.069,155.036,92.603,176.089,79.31,139.99],"xaxis":"x","y":[0.816,0.586,0.885,0.528,0.939,0.429,0.961,0.529],"yaxis":"y","type":"scatter"},{"customdata":[["Moscow Mule"],["Despu\u00e9s de la Playa"],["Me Porto Bonito"],["Tit\u00ed Me Pregunt\u00f3"],["Un Ratito"],["Yo No Soy Celoso"],["Tarot"],["Neverita"],["La Corriente"],["Efecto"],["Party"],["Aguacero"],["Ens\u00e9\u00f1ame a Bailar"],["Ojitos Lindos"],["Dos Mil 16"], ...

# %%
# Box plot graph: Analyzing Tempo Variation in Bad Bunny Music
# Determining the central tendency tempo for bad bunny musics

px.box(df_bad_bunny_album,x="Tempo", color ="Album", title= "Analyzing Tempo Variation in Bad Bunny's Music")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7787543-4de3-425b-a196-10079225c967" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7787543-4de3-425b-a196-10079225c967")) {                    Plotly.newPlot(                        "d7787543-4de3-425b-a196-10079225c967",                        [{"alignmentgroup":"True","hovertemplate":"Album=X 100PRE\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"X 100PRE","marker":{"color":"#636efa"},"name":"X 100PRE","notched":false,"offsetgroup":"X 100PRE","orientation":"h","showlegend":true,"x":[160.02,160.007,103.956,81.998,119.883,128.028,137.048,146.075,88.661,154.946,171.854,179.972,125.8,108.025,97.054],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Album=YHLQMDLG\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YHLQMDLG","marker":{"color":"#EF553B"},"name":"YHLQMDLG","notched":false,"offsetgroup":"YHLQMDLG","orientation":"h","showlegend":true,"x":[151.982,80.353,93.956,154.083,156.019,96.029,129.928,179.87,147.982,93.037,97.014,92.041,93.992,94.026,91.976,92.023,83.836,96.172,139.968,101.024],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Album=LAS QUE NO IBAN A SALIR\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAS QUE NO IBAN A SALIR","marker":{"color":"#00cc96"},"name":"LAS QUE NO IBAN A SALIR","notched":false,"offsetgroup":"LAS QUE NO IBAN A SALIR","orientation":"h","showlegend":true,"x":[93.094,143.995,179.788,79.968,93.0,158.093,147.967,92.976,94.011,90.041],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Album=OASIS\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OASIS","marker":{"color":"#ab63fa"},"name":"OASIS","notched":false,"offsetgroup":"OASIS","orientation":"h","showlegend":true,"x":[103.053,90.98,172.069,155.036,92.603,176.089,79.31,139.99],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Album=Un Verano Sin Ti\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Un Verano Sin Ti","marker":{"color":"#FFA15A"},"name":"Un Verano Sin Ti","notched":false,"offsetgroup":"Un Verano Sin Ti","orientation":"h","showlegend":true,"x":[99.968,78.293,92.005,106.672,93.05,142.004,114.011,122.016,196.12,98.047,97.013,121.391,105.009,79.928,130.058,117.765,108.02,151.991,103.071,85.046,187.844,115.018,176.086],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Album=nadie sabe lo que va a pasar ma\u00f1ana\u003cbr\u003eTempo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"nadie sabe lo que va a pasar ma\u00f1ana","marker":{"color":"#19d3f3"},"name":"nadie sabe lo que va a pasar ma\u00f1ana","notched":false,"offsetgroup":"nadie sabe lo que va a pasar ma\u00f1ana","orientation":"h","showlegend":true,"x":[170.305,139.056,94.601,119.935,126.013,151.823,125.015,125.876,143.916,125.752,117.924,134.046,93.705,122.92,105.009,99.011,143.992,156.027,96.057,85.205,94.991],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks ...

# %%
# bar chart: Popularity Analysis of Bad Bunny's Music
fig = px.bar(df_bad_bunny_album, x="Album", y="Popularity", color="Album", title="Popularity Analysis of Bad Bunny's Music")
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0274098d-f496-4d83-95d9-06d09e92a9bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0274098d-f496-4d83-95d9-06d09e92a9bd")) {                    Plotly.newPlot(                        "0274098d-f496-4d83-95d9-06d09e92a9bd",                        [{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"X 100PRE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"X 100PRE","offsetgroup":"X 100PRE","orientation":"v","showlegend":true,"textposition":"auto","x":["X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE","X 100PRE"],"xaxis":"x","y":[74,76,77,73,79,80,71,72,84,71,88,76,79,74,68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YHLQMDLG","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"YHLQMDLG","offsetgroup":"YHLQMDLG","orientation":"v","showlegend":true,"textposition":"auto","x":["YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG","YHLQMDLG"],"xaxis":"x","y":[79,77,83,77,77,79,87,86,80,88,83,81,86,81,80,90,87,85,72,74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAS QUE NO IBAN A SALIR","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LAS QUE NO IBAN A SALIR","offsetgroup":"LAS QUE NO IBAN A SALIR","orientation":"v","showlegend":true,"textposition":"auto","x":["LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR","LAS QUE NO IBAN A SALIR"],"xaxis":"x","y":[75,73,79,81,0,66,69,72,75,70],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OASIS","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"OASIS","offsetgroup":"OASIS","orientation":"v","showlegend":true,"textposition":"auto","x":["OASIS","OASIS","OASIS","OASIS","OASIS","OASIS","OASIS","OASIS"],"xaxis":"x","y":[75,68,72,72,83,89,81,72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Un Verano Sin Ti","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Un Verano Sin Ti","offsetgroup":"Un Verano Sin Ti","orientation":"v","showlegend":true,"textposition":"auto","x":["Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti","Un Verano Sin Ti"],"xaxis":"x","y":[84,78,89,86,78,76,82,83,80,86,81,76,76,87,79,72,80,81,79,76,77,76,78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Album=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"nadie sabe lo que va a pasar ma\u00f1ana","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"nadie sa ...
